# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Lendo os datasets dos anos

# %%
m12 = pd.read_csv('/content/drive/MyDrive/DataScienceUP/EvasaoEscolar/Datasets/DatasetsFiltrados/evasão_12.csv')
m13 = pd.read_csv('/content/drive/MyDrive/DataScienceUP/EvasaoEscolar/Datasets/DatasetsFiltrados/evasão_13.csv')
m14 = pd.read_csv('/content/drive/MyDrive/DataScienceUP/EvasaoEscolar/Datasets/DatasetsFiltrados/evasão_14.csv')
m15 = pd.read_csv('/content/drive/MyDrive/DataScienceUP/EvasaoEscolar/Datasets/DatasetsFiltrados/evasão_15.csv')
m16 = pd.read_csv('/content/drive/MyDrive/DataScienceUP/EvasaoEscolar/Datasets/DatasetsFiltrados/evasão_16.csv')

# %%
m12.drop(columns=['Unnamed: 0'], inplace=True)
m13.drop(columns=['Unnamed: 0'], inplace=True)
m14.drop(columns=['Unnamed: 0'], inplace=True)
m15.drop(columns=['Unnamed: 0'], inplace=True)
m16.drop(columns=['Unnamed: 0'], inplace=True)

# %%
m12['Ano']=2012
m13['Ano']=2013
m14['Ano']=2014
m15['Ano']=2015
m16['Ano']=2016

# %% [markdown]
# Concatenando os datasets em um único

# %%
evasao = pd.concat([m12, m13, m14, m15, m16])

# %% [markdown]
# Listando as colunas

# %%
evasao.columns.tolist()
# Out:
# ['ID',
#  'Idade',
#  'Necessidade_especial',
#  'Cegueira',
#  'Baixa_visao',
#  'Surdez',
#  'Def_auditiva',
#  'Surdocegueira',
#  'Def_fisica',
#  'Def_intelectual',
#  'Def_multipla',
#  'Autismo',
#  'Asperger',
#  'Rett',
#  'Transtorno_DI',
#  'Superdotacao',
#  'Etapa_ensino',
#  'ID_escola',
#  'Status',
#  'Etnia_Branca',
#  'Etnia_Indígena',
#  'Etnia_Não Declarada',
#  'Etnia_Parda',
#  'Etnia_Preta',
#  'Nacionalidade_Brasileiro',
#  'Nacionalidade_Extrangeiro',
#  'Nacionalidade_Naturalizado',
#  'Zona_res_Urbana',
#  'Outro_local_aula_Hospital',
#  'Outro_local_aula_Não recebe',
#  'Unificada_Multi',
#  'Unificada_Não',
#  'Tipo_turma_Classe Hospitalar',
#  'Tipo_turma_Não se aplica',
#  'Tipo_turma_Unidade prisional',
#  'Localizacao_Rural',
#  'Localizacao_Urbana',
#  'Administracao_Federal',
#  'Administracao_Municipal',
#  'Administracao_Privada',
#  'Ano',
#  'Sexo_M',
#  'Unificada_Multietapa']

# %%
import seaborn as sns
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
evasao.corr()
# Out:
#                                     ID     Idade  Necessidade_especial  \
# ID                            1.000000 -0.434933             -0.044929
# Idade                        -0.434933  1.000000              0.109688
# Necessidade_especial         -0.044929  0.109688              1.000000
# Cegueira                      0.001679  0.005156              0.069203
# Baixa_visao                  -0.006915  0.012842              0.200379
# Surdez                       -0.013640  0.016995              0.185526
# Def_auditiva                 -0.005520  0.010654              0.154015
# Surdocegueira                 0.000999 -0.001261              0.007642
# Def_fisica                   -0.004611  0.016480              0.330031
# Def_intelectual              -0.049423  0.125301              0.804273
# Def_multipla                 -0.005345  0.025019              0.212149
# Autismo                       0.013230 -0.008354              0.250130
# Asperger                     -0.000551  0.005790              0.110754
# Rett                         -0.000756  0.002787              0.018718
# Transtorno_DI                -0.014798  0.022003              0.301916
# Superdotacao                 -0.005891  0.006212              0.200962
# Etapa_ensino                 -0.416235  0.908123             -0.094776
# ID_escola                     0.064822 -0.086698              0.009650
# Etnia_Branca                  0.035498 -0.115714              0.005333
# Etnia_Indígena                0.003213 -0.008548             -0.000298
# Etnia_Não Declarada          -0.019946  0.131856             -0.013190
# Etnia_Parda                  -0.028433 -0.000040              0.009240
# Etnia_Preta                  -0.008497 -0.001158              0.005790
# Nacionalidade_Brasileiro     -0.048113  0.016367             -0.003375
# Nacionalidade_Extrangeiro     0.054915 -0.012331             -0.002782
# Nacionalidade_Naturalizado    0.018858 -0.000252              0.000114
# Zona_res_Urbana               0.014277 -0.039385              0.000061
# Outro_local_aula_Hospital    -0.001737 -0.001380              0.021699
# Outro_local_aula_Não recebe   0.001380  0.003653             -0.022517
# Unificada_Multi              -0.008981  0.039270              0.075527
# Unificada_Não                 0.017050 -0.066208             -0.120802
# Tipo_turma_Classe Hospitalar  0.005014 -0.006947              0.002008
# Tipo_turma_Não se aplica     -0.009018  0.018329             -0.003918
# Tipo_turma_Unidade prisional  0.011239 -0.008336             -0.001490
# Localizacao_Rural            -0.008489  0.011880              0.003690
# Localizacao_Urbana            0.005962  0.001979             -0.002171
# Administracao_Federal        -0.014806  0.038971             -0.005700
# Administracao_Municipal       0.151404 -0.513940              0.046812
# Administracao_Privada         0.146991 -0.098371             -0.005212
# Ano                           0.365901 -0.035667              0.011901
# Sexo_M                       -0.023299  0.033550              0.039440
# Unificada_Multietapa         -0.000032 -0.001857              0.016014
# Status_aprovado              -0.044940 -0.232504             -0.149514
# Status_evadido                0.168149  0.140469              0.046153
# Status_repetente             -0.115535  0.175560              0.159727
#
#                               Cegueira  Baixa_visao    Surdez  Def_auditiva  \
# ID                            0.001679    -0.006915 -0.013640     -0.005520
# Idade                         0.005156     0.012842  0.016995      0.010654
# Necessidade_especial          0.069203     0.200379  0.185526      0.154015
# Cegueira                      1.000000    -0.000286 -0.000265     -0.000220
# Baixa_visao                  -0.000286     1.000000  0.007099      0.008837
# Surdez                       -0.000265     0.007099  1.000000     -0.000590
# Def_auditiva                 -0.000220     0.008837 -0.000590      1.000000
# Surdocegueira                -0.000011    -0.000032 -0.000029     -0.000024
# Def_fisica                    0.002092     0.060638  0.014041      0.008167
# Def_intelectual               0.002041     0.030116  0.000492      0.005569
# Def_multipla                  0.011642     0.167010  0.031882      0.042280
# Autismo                       0.006399     0.001301 -0.000958      0.006798
# Asperger                     -0.000158     0.002176 -0.000424     -0.000352
# Rett                         -0.000027     0.015505 -0.000072     -0.000060
# Transtorno_DI                -0.000431     0.008430 -0.001156      0.005334
# Superdotacao                 -0.000287    -0.000831  0.002368      0.006918
# Etapa_ensino                 -0.000558    -0.003155  0.002924      0.001004
# ID_escola                    -0.003028    -0.000179  0.003986     -0.003788
# Etnia_Branca                  0.001263     0.003313 -0.000079      0.002108
# Etnia_Indígena               -0.000308    -0.000892 -0.000825     -0.000685
# Etnia_Não Declarada          -0.001860    -0.001541 -0.001946     -0.001884
# Etnia_Parda                  -0.000854    -0.002652  0.002547     -0.000022
# Etnia_Preta                   0.004925     0.000325  0.000807     -0.000674
# Nacionalidade_Brasileiro      0.000756    -0.005322 -0.000470      0.001321
# Nacionalidade_Extrangeiro    -0.000638    -0.000535  0.000415     -0.000566
# Nacionalidade_Naturalizado    0.004996     0.004354 -0.001190     -0.000988
# Zona_res_Urbana               0.000529    -0.003206 -0.007109     -0.002931
# Outro_local_aula_Hospital    -0.000110    -0.000318 -0.000294      0.014575
# Outro_local_aula_Não recebe  -0.005798    -0.005638  0.000539     -0.007643
# Unificada_Multi              -0.000112    -0.000307 -0.000310     -0.000196
# Unificada_Não                 0.000192    -0.010321  0.000514      0.000426
# Tipo_turma_Classe Hospitalar -0.000121    -0.000361 -0.000346     -0.000212
# Tipo_turma_Não se aplica      0.000281     0.000771  0.000779      0.000493
# Tipo_turma_Unidade prisional -0.000113    -0.000336 -0.000323     -0.000197
# Localizacao_Rural            -0.000250    -0.000744  0.007204     -0.000437
# Localizacao_Urbana            0.000268    -0.003893 -0.000962      0.000596
# Administracao_Federal        -0.000409    -0.001184 -0.001096     -0.000910
# Administracao_Municipal      -0.006347    -0.003656 -0.012106     -0.003006
# Administracao_Privada         0.006693     0.001038  0.002397      0.000371
# Ano                          -0.001244    -0.000920 -0.006863      0.006553
# Sexo_M                       -0.000287     0.005300  0.002521      0.002943
# Unificada_Multietapa         -0.000024     0.090874 -0.000058     -0.000062
# Status_aprovado              -0.006517    -0.011309 -0.009712     -0.008244
# Status_evadido                0.004555     0.005019  0.000468      0.001551
# Status_repetente              0.004266     0.010461  0.013058      0.009860
#
#                               Surdocegueira  Def_fisica  Def_intelectual  ...  \
# ID                                 0.000999   -0.004611        -0.049423  ...
# Idade                             -0.001261    0.016480         0.125301  ...
# Necessidade_especial               0.007642    0.330031         0.804273  ...
# Cegueira                          -0.000011    0.002092         0.002041  ...
# Baixa_visao                       -0.000032    0.060638         0.030116  ...
# Surdez                            -0.000029    0.014041         0.000492  ...
# Def_auditiva                      -0.000024    0.008167         0.005569  ...
# Surdocegueira                      1.000000   -0.000052        -0.000127  ...
# Def_fisica                        -0.000052    1.000000         0.143110  ...
# Def_intelectual                   -0.000127    0.143110         1.000000  ...
# Def_multipla                      -0.000033    0.585083         0.248503  ...
# Autismo                           -0.000039   -0.000284         0.007629  ...
# Asperger                          -0.000017    0.005652         0.001484  ...
# Rett                              -0.000003   -0.000128        -0.000311  ...
# Transtorno_DI                     -0.000048    0.009125         0.085328  ...
# Superdotacao                      -0.000032   -0.000486        -0.002603  ...
# Etapa_ensino                      -0.001240   -0.035284        -0.098845  ...
# ID_escola                         -0.000499    0.002572         0.013629  ...
# Etnia_Branca                      -0.001485    0.008299        -0.001852  ...
# Etnia_Indígena                    -0.000034    0.000179         0.001205  ...
# Etnia_Não Declarada               -0.000614   -0.006720        -0.007846  ...
# Etnia_Parda                        0.003315   -0.002724         0.012001  ...
# Etnia_Preta                       -0.000113   -0.001883         0.008638  ...
# Nacionalidade_Brasileiro                NaN   -0.001541        -0.003517  ...
# Nacionalidade_Extrangeiro         -0.000070   -0.001047        -0.004433  ...
# Nacionalidade_Naturalizado        -0.000049   -0.000403        -0.000655  ...
# Zona_res_Urbana                    0.000058    0.001083         0.001567  ...
# Outro_local_aula_Hospital         -0.000012    0.022570         0.006390  ...
# Outro_local_aula_Não recebe        0.000022   -0.026776        -0.009171  ...
# Unificada_Multi                         NaN    0.054575         0.080189  ...
# Unificada_Não                      0.000021   -0.022893        -0.143734  ...
# Tipo_turma_Classe Hospitalar            NaN   -0.000550         0.002986  ...
# Tipo_turma_Não se aplica                NaN    0.001181        -0.005222  ...
# Tipo_turma_Unidade prisional            NaN   -0.000513        -0.001238  ...
# Localizacao_Rural                       NaN   -0.001135         0.001440  ...
# Localizacao_Urbana                 0.000030    0.001278        -0.001205  ...
# Administracao_Federal             -0.000045   -0.001950        -0.004752  ...
# Administracao_Municipal            0.001209    0.003742         0.039840  ...
# Administracao_Privada             -0.000628    0.017695        -0.000127  ...
# Ano                                0.000828    0.001466         0.006625  ...
# Sexo_M                             0.001398    0.005884         0.022098  ...
# Unificada_Multietapa              -0.000006   -0.000123        -0.000334  ...
# Status_aprovado                    0.000468   -0.032970        -0.163742  ...
# Status_evadido                    -0.000328    0.011326         0.054588  ...
# Status_repetente                  -0.000306    0.034004         0.170641  ...
#
#                               Localizacao_Urbana  Administracao_Federal  \
# ID                                      0.005962              -0.014806
# Idade                                   0.001979               0.038971
# Necessidade_especial                   -0.002171              -0.005700
# Cegueira                                0.000268              -0.000409
# Baixa_visao                            -0.003893              -0.001184
# Surdez                                 -0.000962              -0.001096
# Def_auditiva                            0.000596              -0.000910
# Surdocegueira                           0.000030              -0.000045
# Def_fisica                              0.001278              -0.001950
# Def_intelectual                        -0.001205              -0.004752
# Def_multipla                            0.000821              -0.001253
# Autismo                                 0.000968              -0.001478
# Asperger                                0.000429              -0.000654
# Rett                                    0.000072              -0.000111
# Transtorno_DI                           0.001169              -0.001784
# Superdotacao                           -0.005429              -0.000170
# Etapa_ensino                            0.004896               0.044126
# ID_escola                              -0.021380              -0.018549
# Etnia_Branca                           -0.001288              -0.010246
# Etnia_Indígena                          0.000834              -0.001274
# Etnia_Não Declarada                     0.005193               0.012350
# Etnia_Parda                            -0.004876              -0.002011
# Etnia_Preta                            -0.002935              -0.002507
# Nacionalidade_Brasileiro                0.363902               0.002867
# Nacionalidade_Extrangeiro               0.001728               0.000119
# Nacionalidade_Naturalizado              0.001204              -0.001837
# Zona_res_Urbana                         0.041585               0.000529
# Outro_local_aula_Hospital               0.000297              -0.000454
# Outro_local_aula_Não recebe            -0.000545               0.000831
# Unificada_Multi                         0.000326              -0.000424
# Unificada_Não                           0.048277               0.000793
# Tipo_turma_Classe Hospitalar            0.000454              -0.000459
# Tipo_turma_Não se aplica                0.640341               0.001067
# Tipo_turma_Unidade prisional            0.000424              -0.000428
# Localizacao_Rural                      -0.590249              -0.000948
# Localizacao_Urbana                      1.000000               0.001108
# Administracao_Federal                   0.001108               1.000000
# Administracao_Municipal                -0.013849              -0.037340
# Administracao_Privada                   0.012503              -0.023521
# Ano                                     0.011886               0.000885
# Sexo_M                                 -0.001779              -0.001475
# Unificada_Multietapa                   -0.092416              -0.000107
# Status_aprovado                         0.006629               0.004756
# Status_evadido                         -0.005517              -0.000811
# Status_repetente                       -0.003403              -0.005778
#
#                               Administracao_Municipal  Administracao_Privada  \
# ID                                           0.151404               0.146991
# Idade                                       -0.513940              -0.098371
# Necessidade_especial                         0.046812              -0.005212
# Cegueira                                    -0.006347               0.006693
# Baixa_visao                                 -0.003656               0.001038
# Surdez                                      -0.012106               0.002397
# Def_auditiva                                -0.003006               0.000371
# Surdocegueira                                0.001209              -0.000628
# Def_fisica                                   0.003742               0.017695
# Def_intelectual                              0.039840              -0.000127
# Def_multipla                                -0.014946               0.033819
# Autismo                                      0.014813               0.000333
# Asperger                                    -0.002724               0.006020
# Rett                                        -0.001541               0.001582
# Transtorno_DI                                0.039605              -0.018217
# Superdotacao                                 0.007788              -0.004975
# Etapa_ensino                                -0.554200              -0.074174
# ID_escola                                   -0.018211               0.141207
# Etnia_Branca                                 0.181969              -0.076735
# Etnia_Indígena                               0.020099              -0.014096
# Etnia_Não Declarada                         -0.294681               0.186879
# Etnia_Parda                                  0.119335              -0.139585
# Etnia_Preta                                  0.034868              -0.037413
# Nacionalidade_Brasileiro                     0.011087              -0.039626
# Nacionalidade_Extrangeiro                   -0.006115               0.030732
# Nacionalidade_Naturalizado                  -0.025124               0.027719
# Zona_res_Urbana                              0.036815               0.016311
# Outro_local_aula_Hospital                    0.010397              -0.006057
# Outro_local_aula_Não recebe                 -0.002375              -0.007396
# Unificada_Multi                             -0.008935               0.018868
# Unificada_Não                               -0.012047               0.000423
# Tipo_turma_Classe Hospitalar                 0.012579              -0.005967
# Tipo_turma_Não se aplica                    -0.023387               0.008507
# Tipo_turma_Unidade prisional                -0.009630               0.020302
# Localizacao_Rural                           -0.000088              -0.009398
# Localizacao_Urbana                          -0.013849               0.012503
# Administracao_Federal                       -0.037340              -0.023521
# Administracao_Municipal                      1.000000              -0.519260
# Administracao_Privada                       -0.519260               1.000000
# Ano                                         -0.003342               0.054791
# Sexo_M                                      -0.002898              -0.007068
# Unificada_Multietapa                         0.002798              -0.001518
# Status_aprovado                              0.095793               0.065063
# Status_evadido                              -0.074996               0.005298
# Status_repetente                            -0.054181              -0.096415
#
#                                    Ano    Sexo_M  Unificada_Multietapa  \
# ID                            0.365901 -0.023299             -0.000032
# Idade                        -0.035667  0.033550             -0.001857
# Necessidade_especial          0.011901  0.039440              0.016014
# Cegueira                     -0.001244 -0.000287             -0.000024
# Baixa_visao                  -0.000920  0.005300              0.090874
# Surdez                       -0.006863  0.002521             -0.000058
# Def_auditiva                  0.006553  0.002943             -0.000062
# Surdocegueira                 0.000828  0.001398             -0.000006
# Def_fisica                    0.001466  0.005884             -0.000123
# Def_intelectual               0.006625  0.022098             -0.000334
# Def_multipla                  0.000629  0.001256             -0.000078
# Autismo                       0.017219  0.029990             -0.000106
# Asperger                      0.004982  0.012632             -0.000045
# Rett                         -0.002407 -0.001487                   NaN
# Transtorno_DI                -0.000469  0.022769             -0.000100
# Superdotacao                  0.003313  0.011413             -0.000072
# Etapa_ensino                 -0.033938  0.003176             -0.001657
# ID_escola                     0.017391 -0.000669              0.016808
# Etnia_Branca                  0.002903 -0.012961              0.001848
# Etnia_Indígena               -0.004290 -0.000413             -0.000075
# Etnia_Não Declarada          -0.000459  0.007153             -0.001390
# Etnia_Parda                  -0.004088  0.009998             -0.000841
# Etnia_Preta                  -0.001085  0.000603             -0.000264
# Nacionalidade_Brasileiro           NaN       NaN                   NaN
# Nacionalidade_Extrangeiro     0.017377  0.003151             -0.000184
# Nacionalidade_Naturalizado    0.007040  0.002146             -0.000125
# Zona_res_Urbana              -0.007025  0.002607              0.000137
# Outro_local_aula_Hospital    -0.002721  0.001811             -0.000029
# Outro_local_aula_Não recebe   0.007895 -0.004264              0.000059
# Unificada_Multi               0.000712       NaN                   NaN
# Unificada_Não                 0.012575 -0.003678             -0.199985
# Tipo_turma_Classe Hospitalar       NaN       NaN                   NaN
# Tipo_turma_Não se aplica      0.022776       NaN                   NaN
# Tipo_turma_Unidade prisional       NaN       NaN                   NaN
# Localizacao_Rural                  NaN       NaN                   NaN
# Localizacao_Urbana            0.011886 -0.001779             -0.092416
# Administracao_Federal         0.000885 -0.001475             -0.000107
# Administracao_Municipal      -0.003342 -0.002898              0.002798
# Administracao_Privada         0.054791 -0.007068             -0.001518
# Ano                           1.000000 -0.002885                   NaN
# Sexo_M                       -0.002885  1.000000              0.002459
# Unificada_Multietapa               NaN  0.002459              1.000000
# Status_aprovado              -0.048303 -0.050430              0.001231
# Status_evadido                0.083210  0.011592             -0.001018
# Status_repetente             -0.020801  0.060545             -0.000593
#
#                               Status_aprovado  Status_evadido  \
# ID                                  -0.044940        0.168149
# Idade                               -0.232504        0.140469
# Necessidade_especial                -0.149514        0.046153
# Cegueira                            -0.006517        0.004555
# Baixa_visao                         -0.011309        0.005019
# Surdez                              -0.009712        0.000468
# Def_auditiva                        -0.008244        0.001551
# Surdocegueira                        0.000468       -0.000328
# Def_fisica                          -0.032970        0.011326
# Def_intelectual                     -0.163742        0.054588
# Def_multipla                        -0.040883        0.018639
# Autismo                             -0.020803        0.004719
# Asperger                            -0.002459        0.001611
# Rett                                -0.001339       -0.000803
# Transtorno_DI                       -0.030053        0.015402
# Superdotacao                         0.000609       -0.001449
# Etapa_ensino                        -0.126826        0.062043
# ID_escola                            0.019318        0.006272
# Etnia_Branca                         0.050644       -0.035927
# Etnia_Indígena                      -0.000405        0.001136
# Etnia_Não Declarada                 -0.029746        0.027542
# Etnia_Parda                         -0.036574        0.015582
# Etnia_Preta                         -0.011538        0.008067
# Nacionalidade_Brasileiro             0.007087       -0.027122
# Nacionalidade_Extrangeiro           -0.014705        0.028157
# Nacionalidade_Naturalizado           0.000303        0.006010
# Zona_res_Urbana                      0.014273       -0.007079
# Outro_local_aula_Hospital           -0.004079        0.002687
# Outro_local_aula_Não recebe          0.005104       -0.004631
# Unificada_Multi                     -0.015525        0.005199
# Unificada_Não                        0.037574       -0.049733
# Tipo_turma_Classe Hospitalar        -0.003822        0.005483
# Tipo_turma_Não se aplica            -0.000874        0.000516
# Tipo_turma_Unidade prisional         0.004348       -0.002681
# Localizacao_Rural                   -0.005449        0.000139
# Localizacao_Urbana                   0.006629       -0.005517
# Administracao_Federal                0.004756       -0.000811
# Administracao_Municipal              0.095793       -0.074996
# Administracao_Privada                0.065063        0.005298
# Ano                                 -0.048303        0.083210
# Sexo_M                              -0.050430        0.011592
# Unificada_Multietapa                 0.001231       -0.001018
# Status_aprovado                      1.000000       -0.700053
# Status_evadido                      -0.700053        1.000000
# Status_repetente                    -0.653427       -0.083125
#
#                               Status_repetente
# ID                                   -0.115535
# Idade                                 0.175560
# Necessidade_especial                  0.159727
# Cegueira                              0.004266
# Baixa_visao                           0.010461
# Surdez                                0.013058
# Def_auditiva                          0.009860
# Surdocegueira                        -0.000306
# Def_fisica                            0.034004
# Def_intelectual                       0.170641
# Def_multipla                          0.037295
# Autismo                               0.024030
# Asperger                              0.001723
# Rett                                  0.002719
# Transtorno_DI                         0.025613
# Superdotacao                          0.000686
# Etapa_ensino                          0.111220
# ID_escola                            -0.033608
# Etnia_Branca                         -0.032590
# Etnia_Indígena                       -0.000639
# Etnia_Não Declarada                   0.012315
# Etnia_Parda                           0.034521
# Etnia_Preta                           0.007549
# Nacionalidade_Brasileiro              0.014273
# Nacionalidade_Extrangeiro            -0.009328
# Nacionalidade_Naturalizado           -0.006793
# Zona_res_Urbana                      -0.012415
# Outro_local_aula_Hospital             0.002843
# Outro_local_aula_Não recebe          -0.002213
# Unificada_Multi                       0.015451
# Unificada_Não                         0.000285
# Tipo_turma_Classe Hospitalar          0.000141
# Tipo_turma_Não se aplica              0.000667
# Tipo_turma_Unidade prisional         -0.003209
# Localizacao_Rural                     0.006782
# Localizacao_Urbana                   -0.003403
# Administracao_Federal                -0.005778
# Administracao_Municipal              -0.054181
# Administracao_Privada                -0.096415
# Ano                                  -0.020801
# Sexo_M                                0.060545
# Unificada_Multietapa                 -0.000593
# Status_aprovado                      -0.653427
# Status_evadido                       -0.083125
# Status_repetente                      1.000000
#
# [45 rows x 45 columns]

# %%
corr = evasao.corr()

# %%
sns.set_theme(style="whitegrid")

ax = sns.boxplot(x=evasao["Idade"])

# %%
import plotly.express as px

# %%
fig = px.box(evasao, x="Idade", y="Status")
fig.show()
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
sns.scatterplot(data=evasao, x=evasao['Idade'], y=evasao['Status'])

# %% [markdown]
# Convertendo os valores de status (variável categórica) para variáveis "dummy"

# %%
evasao = pd.get_dummies(evasao, columns=['Status_evadido'])

# %%
evasao.Idade.describe()
# Out:
# count    829709.000000
# mean         10.066539
# std           2.670104
# min           1.000000
# 25%           8.000000
# 50%          10.000000
# 75%          12.000000
# max          66.000000
# Name: Idade, dtype: float64

# %% [markdown]
# Filtrando valores de idade acima de 5 e abaixo de 18 anos

# %%
evasao = evasao[evasao.Idade>5]
evasao = evasao[evasao.Idade<18]

# %%
evasao.Idade.describe()
# Out:
# count    827663.000000
# mean         10.040625
# std           2.605638
# min           6.000000
# 25%           8.000000
# 50%          10.000000
# 75%          12.000000
# max          17.000000
# Name: Idade, dtype: float64

# %% [markdown]
# Exlcuindo colunas que não serão utilizadas e criando novo csv.

# %%
evasao.drop(columns=['Status_aprovado', 'Status_repetente', 'ID', 'Ano', 'ID_escola'], inplace=True)

# %%
evasao.to_csv('evasao2.csv')

# %%
evasao = evasao.fillna(0)
evasao_features = evasao.drop(columns=['Status_evadido']).values
evasao_target = evasao['Status_evadido'].values

# %%
evasao['Status_evadido'].value_counts()/len(evasao)
# Out:
# 0    0.919484
# 1    0.080516
# Name: Status_evadido, dtype: float64

# %% [markdown]
# Para prof Mary: O código seguinte é a tentativa de aplicação de um modelo de aprendizado de máquina. Devido à ainda não termos chegado nesse ponto na disciplina, podem haver erros no uso das ferramentas.

# %% [markdown]
# Tentativa para balancear dados uma vez que o status evadido é minoritário.

# %%
#Undersampling
y1 = evasao[evasao['Status_evadido']==1]
y0 = evasao[evasao['Status_evadido']==0]

# %%
y0_novo = y0.sample(n=len(y1))

# %%
y_novo = pd.concat([y1, y0_novo])
y_novo['Status_evadido'].unique()
# Out:
# array([1, 0], dtype=uint8)

# %%
x_novo = y_novo.drop(columns=['Status_evadido']).values
y_novo = y_novo['Status_evadido'].values
print(x_novo.shape, y_novo.shape)
# Out:
# (133280, 39) (133280,)

# %% [markdown]
# Tentativa de modelo de treino

# %%
from sklearn.model_selection import train_test_split
evasao_train, evasao_test, status_evadido_train, status_evadido_test = train_test_split(x_novo, y_novo, test_size = 0.2, random_state = 0)

# %% [markdown]
# Utilizando o modelo/algoritmo Random Forest **sendo sinceros, entendemos ser um dos mais famosos para regressão, mas não podemos afirmar ser o melhor

# %%
#Buscando melhores parâmetros- Random Forest
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score
min_samples = [2, 10, 50, 200, 1000]
n_est = [10, 20, 50, 100]
crit = ['entropy', 'gini']
for s in range(len(min_samples)):
  for n in range(len(n_est)):
    for c in range(len(crit)):
      print(s, n, c)
      print("n_estimators = ",  n_est[n], ", criterion = ", crit[c], ", min_samples_split = ", min_samples[s])
      classifier_RF = RandomForestClassifier(n_estimators = n_est[n], criterion = crit[c], min_samples_split = min_samples[s], random_state = 0)
      classifier_RF.fit(evasao_train, status_evadido_train)
      status_evadido_pred_RF = classifier_RF.predict(evasao_test)
      acuracia_RF = accuracy_score(status_evadido_test, status_evadido_pred_RF)
      print("Acuracia: ", acuracia_RF)
      cm_RF = confusion_matrix(status_evadido_test, status_evadido_pred_RF)
      print("Confusion Matrix: ")
      print(cm_RF)
      print()

# %%
#melhores parâmetros- Random Forest
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, accuracy_score
classifier_RF = RandomForestClassifier(n_estimators =  50 , criterion =  "entropy" , min_samples_split =  50, random_state = 0)
classifier_RF.fit(evasao_train, status_evadido_train)
status_evadido_pred_RF = classifier_RF.predict(evasao_test)
acuracia_RF = accuracy_score(status_evadido_test, status_evadido_pred_RF)
print("Acuracia: ", acuracia_RF)
cm_RF = confusion_matrix(status_evadido_test, status_evadido_pred_RF)
print("Confusion Matrix: ")
print(cm_RF)
print()
# Out:
# Acuracia:  0.6440951380552221
# Confusion Matrix:
# [[8579 4773]
#  [4714 8590]]

# %%
#ROC AUC
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, auc
from sklearn.metrics import plot_roc_curve
import matplotlib.pyplot as plt
ax = plt.gca()
rfc_disp = plot_roc_curve(classifier_RF, evasao_test, status_evadido_test, ax=ax, alpha=0.8, color = 'blue')
#svc_disp = plot_roc_curve(classifier_SVM, evasao_test, status_evadido_test, ax=ax, alpha=0.8, color = 'green')
plt.show()

# %%
#Predict_proba
from pandas import DataFrame
from IPython.display import HTML
from random import sample
sample_evasao_test = sample(list(evasao_test),20)
pred_prob_RF = classifier_RF.predict_proba(sample_evasao_test)
HTML('<h1>Random Forest predict_proba</h1>'+DataFrame(pred_prob_RF).to_html())
# Out:
# <h1>Random Forest predict_proba</h1><table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#       <th>1</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.177140</td>
#       <td>0.822860</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.801320</td>
#       <td>0.198680</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>0.111670</td>
#       <td>0.888330</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.210055</td>
#       <td>0.789945</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.625311</td>
#       <td>0.374689</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>0.094846</td>
#       <td>0.905154</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>0.443587</td>
#       <td>0.556413</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>0.550486</td>
#       <td>0.449514</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>0.597877</td>
#       <td>0.402123</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>0.730702</td>
#       <td>0.269298</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>0.404535</td>
#       <td>0.595465</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>0.257652</td>
#       <td>0.742348</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>0.820694</td>
#       <td>0.179306</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>0.639233</td>
#       <td>0.360767</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>0.367474</td>
#       <td>0.632526</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>0.678445</td>
#       <td>0.321555</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>0.704448</td>
#       <td>0.295552</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>0.269293</td>
#       <td>0.730707</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>0.520014</td>
#       <td>0.479986</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>0.706674</td>
#       <td>0.293326</td>
#     </tr>
#   </tbody>
# </table>

# %%
y_predict = classifier_RF.predict(evasao_features)
evasao['y_pred'] = y_predict
evasao['predict_proba_RF'] = classifier_RF.predict_proba(evasao_features)[:,1]
evasao.groupby('Status_evadido')['predict_proba_RF'].hist()
# Out:
# Status_evadido
# 0    AxesSubplot(0.125,0.125;0.775x0.755)
# 1    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: predict_proba_RF, dtype: object

# %%
q = evasao['predict_proba_RF'].quantile([0.00, 0.10, 0.20, 0.30, 0.40, 0.50, 0.60, 0.70, 0.80, 0.90, 1.00])
q
# Out:
# 0.0    0.008636
# 0.1    0.245612
# 0.2    0.310348
# 0.3    0.340125
# 0.4    0.377355
# 0.5    0.421708
# 0.6    0.482593
# 0.7    0.532623
# 0.8    0.573305
# 0.9    0.626470
# 1.0    0.998710
# Name: predict_proba_RF, dtype: float64

# %%
evasao['Status_evadido'].value_counts()/len(evasao)
# Out:
# 0    0.919484
# 1    0.080516
# Name: Status_evadido, dtype: float64

# %%
q = evasao['predict_proba_RF'].quantile([0.30, 0.60, 0.859, 1.00])
q = pd.DataFrame(q)
q.columns = ['prob']
q
# Out:
#            prob
# 0.300  0.340125
# 0.600  0.482593
# 0.859  0.606996
# 1.000  0.998710

# %%
analise_RF = {'Risco de Evasao':["Baixo", "Médio-baixo", "Médio-alto", "Alto"], 'Probab. de Evasão': ["Até 11%", "entre 11% e 24,5%", "entre 24,5% e 80%", "entre 80% e 100%"], '% da população': ["30%", "30%", "25,6%", "14,4%"]}
analise_RF = pd.DataFrame.from_dict(analise_RF, orient='columns')
analise_RF
# Out:
#   Risco de Evasao  Probab. de Evasão % da população
# 0           Baixo            Até 11%            30%
# 1     Médio-baixo  entre 11% e 24,5%            30%
# 2      Médio-alto  entre 24,5% e 80%          25,6%
# 3            Alto   entre 80% e 100%          14,4%

# %%
# random forest for feature importance on a classification problem
from sklearn.datasets import make_classification
from sklearn.ensemble import RandomForestClassifier
from matplotlib import pyplot
# get importance
importance = classifier_RF.feature_importances_
# summarize feature importance
for i,v in enumerate(importance):
	print('Feature: %0d, Score: %.5f' % (i,v))
# plot feature importance
pyplot.bar([x for x in range(len(importance))], importance)
pyplot.show()
# Out:
# Feature: 0, Score: 0.52767
# Feature: 1, Score: 0.01143
# Feature: 2, Score: 0.00042
# Feature: 3, Score: 0.00167
# Feature: 4, Score: 0.00180
# Feature: 5, Score: 0.00108
# Feature: 6, Score: 0.00000
# Feature: 7, Score: 0.00248
# Feature: 8, Score: 0.00992
# Feature: 9, Score: 0.00086
# Feature: 10, Score: 0.00147
# Feature: 11, Score: 0.00064
# Feature: 12, Score: 0.00000
# Feature: 13, Score: 0.00219
# Feature: 14, Score: 0.00139
# Feature: 15, Score: 0.14361
# Feature: 16, Score: 0.01412
# Feature: 17, Score: 0.00176
# Feature: 18, Score: 0.00868
# Feature: 19, Score: 0.00739
# Feature: 20, Score: 0.00384
# Feature: 21, Score: 0.02861
# Feature: 22, Score: 0.01603
# Feature: 23, Score: 0.00622
# Feature: 24, Score: 0.00771
# Feature: 25, Score: 0.00030
# Feature: 26, Score: 0.00240
# Feature: 27, Score: 0.00004
# Feature: 28, Score: 0.00138
# Feature: 29, Score: 0.00003
# Feature: 30, Score: 0.07632
# Feature: 31, Score: 0.00000
# Feature: 32, Score: 0.00020
# Feature: 33, Score: 0.00340
# Feature: 34, Score: 0.00485
# Feature: 35, Score: 0.06325
# Feature: 36, Score: 0.03186
# Feature: 37, Score: 0.01497
# Feature: 38, Score: 0.00000

# %%
import numpy as np

importances = classifier_RF.feature_importances_
std = np.std([
    tree.feature_importances_ for tree in classifier_RF.estimators_], axis=0)

# %%
forest_importances = pd.Series(importances, index=evasao.drop(columns=['Status_evadido', 'y_pred', 'predict_proba_RF',
                                                                       ]).columns.tolist())

fig, ax = plt.subplots()
forest_importances.sort_values(ascending=False).plot.bar()
ax.set_title("Feature importances using MDI")
ax.set_ylabel("Mean decrease in impurity")
fig.tight_layout()

# %%
evasao2 = evasao[['Status_evadido', 'Idade']]

# %%
total = evasao2.groupby('Idade').count()

# %%
evadido = evasao2[evasao2.Status_evadido==1].groupby('Idade').count()

# %%
evadido/total
# Out:
#        Status_evadido
# Idade
# 6.0          0.061322
# 7.0          0.057862
# 8.0          0.056356
# 9.0          0.051702
# 10.0         0.080094
# 11.0         0.079981
# 12.0         0.070513
# 13.0         0.064981
# 14.0         0.128464
# 15.0         0.339177
# 16.0         0.478665
# 17.0         0.615354

# %%
#curva roc, score probabilidade para todo o dataset classe.predict_proba, estudo de KomogorovSmirnoff (distâncias das classes negativas vs. classes positivas)
#histogram das distribuições de cada classe/decis e criar uma label por decis, feature importance, otimizar modelo grid search
#MLOPS - ML Operations (operacionalizar o modelo provido pelo cientista de dados)
#DataOps - Entrega em estruturas
